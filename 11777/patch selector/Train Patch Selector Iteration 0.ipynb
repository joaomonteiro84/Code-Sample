# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/11-777 Multimodal/Patch Selector/')

# %% [markdown]
# Learning rate 5e-05

# %%
# !python patch_selector.py --lr 5e-05 --batch-size 4 --number-epochs 5
# Out:
# 2023-12-03 00:36:46.780089: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:36:46.780145: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:36:46.780188: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:36:47.961875: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 4, lr: 5e-05,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.81it/s]
# ...

# %%
# !python patch_selector.py --lr 5e-05 --batch-size 8 --number-epochs 5
# Out:
# 2023-12-03 00:40:43.369126: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:40:43.369174: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:40:43.369204: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:40:44.531926: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 8, lr: 5e-05,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.57it/s]
# ...

# %%
# !python patch_selector.py --lr 5e-05 --batch-size 12 --number-epochs 5
# Out:
# 2023-12-03 00:43:37.574685: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:43:37.574736: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:43:37.574768: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:43:38.732254: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 12, lr: 5e-05,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:46<00:00, 50.71it/s]
# ...

# %%
# !python patch_selector.py --lr 5e-05 --batch-size 16 --number-epochs 5
# Out:
# 2023-12-03 00:46:14.467762: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:46:14.467813: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:46:14.467840: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:46:15.621542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 16, lr: 5e-05,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.65it/s]
# ...

# %% [markdown]
# Learning rate 5e-04

# %%
# !python patch_selector.py --lr 5e-04 --batch-size 4 --number-epochs 5
# Out:
# 2023-12-03 00:48:44.127356: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:48:44.127407: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:48:44.127439: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:48:45.299396: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 4, lr: 0.0005,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.48it/s]
# ...

# %%
# !python patch_selector.py --lr 5e-04 --batch-size 8 --number-epochs 5
# Out:
# 2023-12-03 00:52:42.993825: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:52:42.993879: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:52:42.993912: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:52:44.147154: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 8, lr: 0.0005,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.76it/s]
# ...

# %%
# !python patch_selector.py --lr 5e-04 --batch-size 12 --number-epochs 5
# Out:
# 2023-12-03 00:55:35.571738: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:55:35.571785: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:55:35.571815: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:55:36.741136: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 12, lr: 0.0005,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.89it/s]
# ...

# %%
# !python patch_selector.py --lr 5e-04 --batch-size 16 --number-epochs 5
# Out:
# 2023-12-03 00:58:08.937375: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 00:58:08.937451: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 00:58:08.937483: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 00:58:10.139359: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 16, lr: 0.0005,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:46<00:00, 51.00it/s]
# ...

# %% [markdown]
# Learning Rate 2.75e-04

# %%
# !python patch_selector.py --lr 2.75e-04 --batch-size 4 --number-epochs 5
# Out:
# 2023-12-03 01:00:38.670042: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 01:00:38.670094: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 01:00:38.670122: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 01:00:39.840717: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 4, lr: 0.000275,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.47it/s]
# ...

# %%
# !python patch_selector.py --lr 2.75e-04 --batch-size 8 --number-epochs 5
# Out:
# 2023-12-03 01:04:36.853174: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 01:04:36.853223: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 01:04:36.853249: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 01:04:38.261285: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 8, lr: 0.000275,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:48<00:00, 48.63it/s]
# ...

# %%
# !python patch_selector.py --lr 2.75e-04 --batch-size 12 --number-epochs 5
# Out:
# 2023-12-03 01:07:34.885662: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 01:07:34.885711: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 01:07:34.885765: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 01:07:36.190076: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 12, lr: 0.000275,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.46it/s]
# ...

# %%
# !python patch_selector.py --lr 2.75e-04 --batch-size 16 --number-epochs 5
# Out:
# 2023-12-03 01:10:11.100105: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-03 01:10:11.100165: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-03 01:10:11.100194: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-03 01:10:12.251493: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# training data file: annotated_train_data_0.json, validation data file: annotated_val_data.json, number of epochs:5
# batch size: 16, lr: 0.000275,pos weight: 3.47
# Processing images: 100% 2355/2355 [00:45<00:00, 51.51it/s]
# ...
