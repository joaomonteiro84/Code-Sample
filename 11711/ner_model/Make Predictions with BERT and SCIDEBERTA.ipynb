# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install transformers
# !pip install transformers[torch]
# !pip install evaluate
# !pip install seqeval
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 55.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 102.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
os.chdir("/content/drive/MyDrive/11711/Assignment 2/")

# %%
# Make predictions using ner model with BERT

# Public test
#!python ner_model/ner_predict.py --ner-model-name bert --test-data data/public/test.csv --ner-pred-save-file output/bert_test_public.csv

# Private test
# !python ner_model/ner_predict.py --ner-model-name bert --test-data data/private/test_private.csv --ner-pred-save-file output/bert_test_private.csv
# Out:
# 2023-10-27 02:53:13.120576: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 02:53:13.120654: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 02:53:13.120703: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 02:53:14.303626: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 699/699 [00:00<00:00, 1707.90 examples/s]
# ...

# %%
# Make predictions using ner model with SCIDEBERTA

# Public test
#!python ner_model/ner_predict.py --ner-model-name scideberta --test-data data/public/test.csv --ner-pred-save-file output/scideberta_test_public.csv

# Private test
# !python ner_model/ner_predict.py --ner-model-name scideberta --test-data data/private/test_private.csv --ner-pred-save-file output/scideberta_test_private.csv
# Out:
# 2023-10-27 02:48:56.877554: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 02:48:56.877614: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 02:48:56.877656: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 02:48:58.091352: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 699/699 [00:00<00:00, 1557.58 examples/s]
# ...

# %%
# !ls
# Out:
#  annotated_data		      data		    output		    test_pred.csv
# 'Assignment 2 - TODOs.gdoc'  'Meeting 10 14.gdoc'   papers_to_annotate
#  bert			     'Meeting 10 23.gdoc'  'power analysis.ipynb'
#  bert_ner		      ner_model		    scideberta

# %% [markdown]
# Predict on our test data. First modify format type

# %%
# !ls
# Out:
#  annotated_data		      data		    output		    test_pred.csv
# 'Assignment 2 - TODOs.gdoc'  'Meeting 10 14.gdoc'   papers_to_annotate
#  bert			     'Meeting 10 23.gdoc'  'power analysis.ipynb'
#  bert_ner		      ner_model		    scideberta

# %%
from ner_model.helper_functions import prep_data

with open('data/test.conll', 'r') as file:
  lines = file.readlines()

sid, sentences, _, _ = prep_data(lines, 600)

# %%
with open('data/test_lines.conll', 'w', encoding='utf-8') as file:
  for s in sentences:
    line = ' '.join(s)+'\n'
    file.write(line)

# %%
with open('data/test_lines.txt', 'w', encoding='utf-8') as file:
  for s in sentences:
    line = ' '.join(s)+'\n'
    file.write(line)

# %%
# Make predictions using ner model with BERT

# Our test
# !python ner_model/ner_predict.py --ner-model-name bert --test-data data/test_lines.conll --ner-pred-save-file output/bert_our_test.conll
# Out:
# 2023-10-27 02:35:40.190461: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 02:35:40.190534: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 02:35:40.190579: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 02:35:41.332421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 1243/1243 [00:01<00:00, 1065.50 examples/s]
# ...

# %%
# Make predictions using ner model with SCIDEBERTA

# Our test
# !python ner_model/ner_predict.py --ner-model-name scideberta --test-data data/test_lines.conll --ner-pred-save-file output/scideberta_our_test.conll --batch-size 4
# Out:
# 2023-10-27 02:40:28.872021: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 02:40:28.872078: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 02:40:28.872124: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-27 02:40:30.469936: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 1243/1243 [00:00<00:00, 1946.29 examples/s]
# ...

# %% [markdown]
# predict for validation - for power analysis

# %%
from ner_model.helper_functions import prep_data

with open('data/validation.conll', 'r') as file:
  lines = file.readlines()

sid, sentences, _, _ = prep_data(lines, 1500)

# %%
with open('data/validation_lines.txt', 'w', encoding='utf-8') as file:
  for s in sentences:
    line = ' '.join(s)+'\n'
    file.write(line)

# %%
# Make predictions using ner model with BERT

# validation
# !python ner_model/ner_predict.py --ner-model-name bert --test-data data/validation_lines.txt --ner-pred-save-file output/bert_validation.conll
# Out:
# 2023-10-29 22:32:44.921955: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 22:32:44.922025: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 22:32:44.922088: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-29 22:32:46.084232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 904/904 [00:00<00:00, 1757.36 examples/s]
# ...

# %%
# Make predictions using ner model with SCIDEBERTA

# Our test
# !python ner_model/ner_predict.py --ner-model-name scideberta --test-data data/validation_lines.txt --ner-pred-save-file output/scideberta_validation.conll --batch-size 4
# Out:
# 2023-10-29 22:34:47.725187: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 22:34:47.725241: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 22:34:47.725282: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-29 22:34:48.927570: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Map: 100% 904/904 [00:00<00:00, 1905.05 examples/s]
# ...

# %%
from ner_model.helper_functions import prep_data

with open('data/train.conll', 'r') as file:
  lines = file.readlines()

sid, sentences, _, _ = prep_data(lines, 1000)

# %%
len(sentences)
# Out:
# 4659

# %%
with open('data/validation.conll', 'r') as file:
  lines = file.readlines()

sid, sentences, _, _ = prep_data(lines, 1000)

# %%
len(sentences)
# Out:
# 892

# %%
with open('data/test.conll', 'r') as file:
  lines = file.readlines()

sid, sentences, _, _ = prep_data(lines, 1000)

# %%
len(sentences)
# Out:
# 1234
